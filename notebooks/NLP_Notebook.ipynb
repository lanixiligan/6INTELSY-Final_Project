# %%
import sys
import os

if os.getcwd().endswith("notebooks"):
    os.chdir("..")

if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

print(f"✅ Path fixed! Current Working Directory: {os.getcwd()}")
# Out:
# ✅ Path fixed! Current Working Directory: c:\Users\Alyssa Iligan\Desktop\PROJECT\6INTELSY-Final_Project

# %%
from src.nlp_component import BottleReporter

# Initialize the NLP Module
reporter = BottleReporter()

# Simulate different factory scenarios
scenarios = [
    {"label": 0, "conf": 0.99, "desc": "Perfect Bottle"},
    {"label": 1, "conf": 0.95, "desc": "Major Crack"},
    {"label": 1, "conf": 0.62, "desc": "Uncertain Anomaly"}
]

print("--- Automated Industrial Logs ---")
for s in scenarios:
    log = reporter.get_report(label=s['label'], conf=s['conf'])
    print(f"Scenario [{s['desc']}]:\n >> {log}\n")
# Out:
# --- Automated Industrial Logs ---
# Scenario [Perfect Bottle]:
#  >> Industrial Report: Bottle state is GOOD (Confidence: 0.99).
#
# Scenario [Major Crack]:
#  >> Industrial Report: Bottle state is DEFECTIVE (Confidence: 0.95).
#
# Scenario [Uncertain Anomaly]:
#  >> Industrial Report: Bottle state is DEFECTIVE (Confidence: 0.62).
