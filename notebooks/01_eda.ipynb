# %%
import os
from pathlib import Path

# Change to project root directory
os.chdir("C:/Users/Alyssa Iligan/Desktop/INTELSY")

# Now list contents
print("Current working directory:", os.getcwd())
print("\nProject contents:")
print(os.listdir("."))
# Out:
# Current working directory: C:\Users\Alyssa Iligan\Desktop\INTELSY
#
# Project contents:
# ['.git']
